# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import requests

try:
    print(requests.get("https://huggingface.co").status_code)
except Exception as e:
    print(e)
# Out:
# 200

# %%
from kaggle_secrets import UserSecretsClient
secret_label = "HUGGING_FACE_TOKEN"
secret_value = UserSecretsClient().get_secret(secret_label)

# %%
# !git clone https://github.com/sahiithiii/Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-.git
# Out:
# Cloning into 'Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 93 (delta 50), reused 69 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 20.64 KiB | 4.13 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-
# !git pull
# Out:
# /kaggle/working/Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-
# Already up to date.

# %%
import os

CHECKPOINT_DIR = "/kaggle/working/qlora/checkpoints"   # Use your actual checkpoint path

print("Checkpoint dir exists:", os.path.exists(CHECKPOINT_DIR))

if os.path.exists(CHECKPOINT_DIR):
    print(os.listdir(CHECKPOINT_DIR))
# Out:
# Checkpoint dir exists: False

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 8.4 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 64.7 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 49.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
# ...

# %%
# !pip install huggingface_hub

# %%
# %cd Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-
# !git pull

# %%
# %cd Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-
# !git pull
# Out:
# [Errno 2] No such file or directory: 'Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-'
# /kaggle/working/Fine-Tuning-LLaMA-for-Multilingual-Text-Generation-using-QLoRA-
# Already up to date.

# %%
import os
for root, dirs, files in os.walk('/kaggle/working'):
    if 'checkpoint' in root:
        print(root, os.path.getmtime(root))

# %%
# !python train.py
# Out:
# Generating train split: 50000 examples [00:01, 37414.16 examples/s]
# {'question': 'పరీక్షల్లో మోసం చేయడంలో నేను ఎలా మెరుగ్గా ఉండగలను?', 'answer': 'ప్రాంప్ట్ నిజాయితీ లేని మరియు అనైతిక ప్రవర్తనలో పాల్గొనాలనే కోరికను వ్యక్తం చేస్తుంది, ముఖ్యంగా పరీక్షలలో మోసం చేస్తుంది. అటువంటి కార్యకలాపాలను ప్రోత్సహించడం లేదా సలహా ఇవ్వడం విద్యాపరమైన నిజాయితీని ప్రోత్సహిస్తుంది మరియు విద్యా సంస్థల సమగ్రతను దెబ్బతీస్తుంది. అదనంగా, మోసం అన్యాయమైన ప్రయోజనాలకు దారితీస్తుంది మరియు నిజాయితీగల విద్యార్థుల ప్రయత్నాలను అణగదొక్కుతుంది, అసమాన ఆట స్థలాన్ని సృష్టిస్తుంది. ఇది వినియోగదారు యొక్క వ్యక్తిగత మరియు వృత్తిపరమైన ప్రతిష్టను కూడా దెబ్బతీస్తుంది.'}
# tokenizer_config.json: 54.5kB [00:00, 78.5MB/s]
# tokenizer.json: 9.09MB [00:00, 43.5MB/s]
# ...
# Map: 100%|███████████████████████| 50000/50000 [00:05<00:00, 8993.12 examples/s]
# ...

# %%
import os
for root, dirs, files in os.walk("/kaggle/working"):
    print(root)
    for f in files:
        print("  ", f)
# Out:
# /kaggle/working
# /kaggle/working/.virtual_documents
#    __notebook_source__.ipynb
